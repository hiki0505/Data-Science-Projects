# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
Train=df.iloc[:2300,:]
Test=df.iloc[2300:,:]

# %%
full_data = pd.concat((Train, Test), sort=False).reset_index(drop=True)
full_data.drop(['price'], axis=1, inplace=True)
full_data.drop(['date'], axis=1, inplace=True)
full_data.drop(['date'], axis=1, inplace=True)
print("Total size is :",full_data.shape)
# Out:
# Total size is : (4600, 16)

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.shape
# Out:
# (4600, 18)

# %%
Train
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00   313000.0       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2384000.0       5.0       2.50         3650
# 2     2014-05-02 00:00:00   342000.0       3.0       2.00         1930
# 3     2014-05-02 00:00:00   420000.0       3.0       2.25         2000
# 4     2014-05-02 00:00:00   550000.0       4.0       2.50         1940
# ...                   ...        ...       ...        ...          ...
# 2295  2014-06-11 00:00:00   200000.0       2.0       1.00          700
# 2296  2014-06-11 00:00:00   295000.0       5.0       3.50         2100
# 2297  2014-06-11 00:00:00   580379.0       4.0       2.75         2240
# 2298  2014-06-11 00:00:00   875000.0       4.0       2.50         3470
# 2299  2014-06-11 00:00:00   515000.0       3.0       2.50         3370
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
num=Train.select_dtypes(exclude='object')
numcorr=num.corr()
f,ax=plt.subplots(figsize=(17,1))
sns.heatmap(numcorr.sort_values(by=['price'], ascending=False).head(1), cmap='Blues')
plt.title(" Numerical features correlation with the price", weight='bold', fontsize=18)
plt.xticks(weight='bold')
plt.yticks(weight='bold', color='dodgerblue', rotation=0)


plt.show()

# %%
Num=numcorr['price'].sort_values(ascending=False).head(10).to_frame()

cm = sns.light_palette("cyan", as_cmap=True)

s = Num.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
#     #T_8f7cc206_9f45_11ea_a568_00e07099919frow0_col0 {
#             background-color:  #00ffff;
#             color:  #000000;
#         }    #T_8f7cc206_9f45_11ea_a568_00e07099919frow1_col0 {
#             background-color:  #4affff;
#             color:  #000000;
#         }    #T_8f7cc206_9f45_11ea_a568_00e07099919frow2_col0 {
#             background-color:  #60ffff;
#             color:  #000000;
#         }    #T_8f7cc206_9f45_11ea_a568_00e07099919frow3_col0 {
#             background-color:  #79ffff;
#             color:  #000000;
#         }    #T_8f7cc206_9f45_11ea_a568_00e07099919frow4_col0 {
#             background-color:  #9affff;
#             color:  #000000;
#         }    #T_8f7cc206_9f45_11ea_a568_00e07099919frow5_col0 {
#             background-color:  #9fffff;
#             color:  #000000;
#         }    #T_8f7cc206_9f45_11ea_a568_00e07099919frow6_col0 {
#             background-color:  #a7ffff;
#             color:  #000000;
# ...

# %%
plt.figure(figsize=(15,6))
plt.scatter(x=Train['sqft_living'], y=Train['price'], color='crimson', alpha=0.5)
plt.title('sqft_living/ price', weight='bold', fontsize=16)
plt.xlabel('sqft_living', weight='bold', fontsize=12)
plt.ylabel('price', weight='bold', fontsize=12)
plt.xticks(weight='bold')
plt.yticks(weight='bold')
plt.show()

# %%
fig = plt.figure(figsize=(15,15))
ax1 = plt.subplot2grid((3,2),(0,0))
plt.scatter(x=Train['sqft_living'], y=Train['price'], color=('yellowgreen'), alpha=0.5)
# plt.axvline(x=4600, color='r', linestyle='-')
plt.title('sqft_living- Price scatter plot', fontsize=15, weight='bold' )

ax1 = plt.subplot2grid((3,2),(0,1))
plt.scatter(x=Train['sqft_above'], y=Train['price'], color=('red'),alpha=0.5)
# plt.axvline(x=5900, color='r', linestyle='-')
plt.title('sqft_above - Price scatter plot', fontsize=15, weight='bold' )

ax1 = plt.subplot2grid((3,2),(1,0))
plt.scatter(x=Train['bathrooms'], y=Train['price'], color=('deepskyblue'),alpha=0.5)
# plt.axvline(x=4000, color='r', linestyle='-')
plt.title('bathrooms - Price scatter plot', fontsize=15, weight='bold' )

ax1 = plt.subplot2grid((3,2),(1,1))
plt.scatter(x=Train['sqft_basement'], y=Train['price'], color=('gold'),alpha=0.9)
# plt.axvline(x=1500, color='r', linestyle='-')
plt.title('sqft_basement - Price scatter plot', fontsize=15, weight='bold' )

ax1 = plt.subplot2grid((3,2),(2,0))
plt.scatter(x=Train['bedrooms'], y=Train['price'], color=('orchid'),alpha=0.5)
# plt.axvline(x=1230, color='r', linestyle='-')
plt.title('bedrooms - Price scatter plot', fontsize=15, weight='bold' )

ax1 = plt.subplot2grid((3,2),(2,1))
plt.scatter(x=Train['view'], y=Train['price'], color=('tan'),alpha=0.9)
# plt.axvline(x=13, color='r', linestyle='-')
plt.title('view - Price scatter plot', fontsize=15, weight='bold' )
plt.show()

# %%
Train['sqft_living'].sort_values(ascending=False).head(2)
# Out:
# 122     13540
# 2286    10040
# Name: sqft_living, dtype: int64

# %%
Train['sqft_above'].sort_values(ascending=False).head(2)
# Out:
# 122     9410
# 2286    7680
# Name: sqft_above, dtype: int64

# %%
Train['bathrooms'].sort_values(ascending=False).head(2)
# Out:
# 122    8.0
# 462    6.5
# Name: bathrooms, dtype: float64

# %%
train=Train[(Train['price'] < 6000000) & (Train['sqft_above'] < 7500) & (Train['bathrooms'] < 7.0) & (Train['sqft_living'] < 10000)]
print('We removed ',Train.shape[0]- train.shape[0],'outliers')
# Out:
# We removed  2 outliers

# %%
target=Train[['price']]
target.loc[2286]
# Out:
# price    7062500.0
# Name: 2286, dtype: float64

# %%
pos = [2286,122]
target.drop(target.index[pos], inplace=True)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
print('We make sure that both train and target sets have the same row number after removing the outliers:')
print( 'Train: ',train.shape[0], 'rows')
print('Target:', target.shape[0],'rows')
# Out:
# We make sure that both train and target sets have the same row number after removing the outliers:
# Train:  2298 rows
# Target: 2298 rows

# %%
train.drop('date', axis=1)
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      313000.0       3.0       1.50         1340      7912     1.5
# 1     2384000.0       5.0       2.50         3650      9050     2.0
# 2      342000.0       3.0       2.00         1930     11947     1.0
# 3      420000.0       3.0       2.25         2000      8030     1.0
# 4      550000.0       4.0       2.50         1940     10500     1.0
# ...         ...       ...        ...          ...       ...     ...
# 2295   200000.0       2.0       1.00          700      4700     1.0
# 2296   295000.0       5.0       3.50         2100      5107     2.0
# 2297   580379.0       4.0       2.75         2240     27820     1.5
# 2298   875000.0       4.0       2.50         3470     32109     2.0
# 2299   515000.0       3.0       2.50         3370     19585     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0              0     0          3        1340              0      1955
# ...

# %%
import sklearn.model_selection as GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
x = train
y = np.array(target)

# %%
def regularization(x,y,modelo=Ridge, scaler=RobustScaler):
    """"
    Function to automate regression with regularization techniques.
    x expects the features
    y expects the target
    modelo: Ridge(default), Lasso, ElasticNetCV
    scaler: RobustSclaer(default), MinMaxSclaer, StandardScaler
    SOURCE: https://www.kaggle.com/amiiiney/price-prediction-regularization-stacking
    Contact: amineyamlahi@gmail.com
    """
    #Split the data to train/test
    x_train, x_test, y_train, y_test = train_test_split(x, y,test_size = .3, random_state=0)
    
    #Scale the data. RobustSclaer default
    
    scaler= scaler()
    # transform "x_train"
    x_train = scaler.fit_transform(x_train)
    # transform "x_test"
    x_test = scaler.transform(x_test)
    #Transform the test set
    X_test= scaler.transform(Test)
    
    if modelo != ElasticNetCV:
        if modelo == Ridge:
            parameters= {'alpha':[x for x in range(1,101)]}
        elif modelo == Lasso:
            parameters= {'alpha':[0.0001,0.0009,0.001,0.002,0.003,0.01,0.1,1,10,100]}
            
        model=modelo()
            
        model=ms.GridSearchCV(model, param_grid=parameters, scoring='neg_mean_squared_error', cv=15)
        model.fit(x_train,y_train)
        y_pred= model.predict(x_test)

        #print("The best value of Alpha is: ",model.best_params_)
        print("The best RMSE score achieved with %s is: %s " %(model.best_params_,
                  str(math.sqrt(sklm.mean_squared_error(y_test, y_pred)))))
    elif modelo == ElasticNetCV:
        alphas = [0.000542555]
        l1ratio = [0.1, 0.3,0.5, 0.9, 0.95, 0.99, 1]

        elastic_cv = ElasticNetCV(cv=5, max_iter=1e7, alphas=alphas,  l1_ratio=l1ratio)

        elasticmod = elastic_cv.fit(x_train, y_train.ravel())
        ela_pred=elasticmod.predict(x_test)
        print("The best RMSE score achieved with alpha %s and l1_ratio %s is: %s "
              %(elastic_cv.alpha_,elastic_cv.l1_ratio_,
            str(math.sqrt(sklm.mean_squared_error(y_test, ela_pred)))))

# %%
regularization(x,y,Ridge)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-70d4e1e16fad> in <module>
# ----> 1 regularization(x,y,Ridge)
#
# <ipython-input-25-245c5f0d0926> in regularization(x, y, modelo, scaler)
#      16     scaler= scaler()
#      17     # transform "x_train"
# ---> 18     x_train = scaler.fit_transform(x_train)
#      19     # transform "x_test"
#      20     x_test = scaler.transform(x_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     551         if y is None:
#     552             # fit method of arity 1 (unsupervised transformation)
# --> 553             return self.fit(X, **fit_params).transform(X)
#     554         else:
#     555             # fit method of arity 2 (supervised transformation)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
# ...

# %%
df_Test

# %%
df_Test.drop(['price'],axis=1,inplace=True)

# %%
df_Test

# %%
X = df_Train.drop(['price'], axis=1)
y = df_Train.price

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=1234)

# %%
X.dtypes

# %%
categorical_features_indices = np.where(X.dtypes == np.object)[0]
categorical_features_indices

# %%
from catboost import CatBoostRegressor
model=CatBoostRegressor(iterations=50, depth=3, learning_rate=0.1, loss_function='RMSE')
model.fit(X_train, y_train,cat_features=categorical_features_indices,eval_set=(X_test, y_test),plot=True)

# %%
submission = pd.DataFrame()

# %%
submission['Item_Outlet_Sales'] = model.predict(df_Test)

# %%
submission

# %%
df_Test2=df.iloc[2300:,:]

# %%
submission['True_Item_Outlet_Sales'] = df_Test2['price']

# %%
df_Test2

# %%
submission
