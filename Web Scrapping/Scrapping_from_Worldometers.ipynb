# %%
import requests, six
import lxml.html as lh
from itertools import cycle, islice
from matplotlib import colors
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
url = 'https://worldometers.info/coronavirus/#countries'

# %%
#Create a handle, page, to handle the contents of the website
page = requests.get(url)

#Store the contents of the website under doc
doc = lh.fromstring(page.content)

#Parse data that are stored between <tr>..</tr> of the site's HTML code
tr_elements = doc.xpath('//tr')

#Check the length of the first 12 rows
[len(T) for T in tr_elements[:12]]
# Out:
# [13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13]

# %%
tr_elements = doc.xpath('//tr')

#Create empty list and index iterator for each header
col = []
i=0

#For each row, store each first element, which is header, and an empty list
for t in tr_elements[0]:
  i+=1
  name=t.text_content()
  print ('%d:"%s"'%(i,name))
  col.append((name,[]))
# Out:
# 1:"Country,Other"
# 2:"TotalCases"
# 3:"NewCases"
# 4:"TotalDeaths"
# 5:"NewDeaths"
# 6:"TotalRecovered"
# 7:"ActiveCases"
# 8:"Serious,Critical"
# 9:"Tot Cases/1M pop"
# 10:"Deaths/1M pop"
# 11:"TotalTests"
# 12:"Tests/
# 1M pop
# "
# 13:"Continent"

# %%
#Since out first row is the header, data is stored on the second row
for j in range(1, len(tr_elements)):
  #T is our j'th row
  T = tr_elements[j]

  #If row is not of size 13, the //tr data is not from our table
  if len(T)!=13:
    break
  #i is the index of our column
  i=0
  #Iterate through each element of the row
  for t in T.iterchildren():
    data = t.text_content()
    #Check if row is empty
    if i>0:
    #Convert any numerical value to integers
      try:
        data=int(data)
      except:
        pass
    #Append the data to the empty list of the i'th column
    col[i][1].append(data)
    #Increment i for the next column
    i+=1

# %%
[len(C) for (title,C) in col]
# Out:
# [457, 457, 457, 457, 457, 457, 457, 457, 457, 457, 457, 457, 457]

# %%
Dict={title:column for (title,column) in col}
import pandas as pd
df = pd.DataFrame(Dict)

# %%
Dict
# Out:
# {'ActiveCases': ['579,068',
#   '611,528',
#   '154,878',
#   '34,178',
#   '3,437',
#   '12,782',
#   68,
#   '1,395,939',
#   '549,362',
#   '88,201',
#   '104,291',
#   '98,769',
#   '56,115',
#   '81,422',
#   '21,679',
#   '58,909',
#   '22,026',
#   '24,224',
#   '17,925',
#   '10,133',
#   '10,106',
#   '22,306',
#   '17,109',
#   '5,799',
#   '9,765',
#   '9,797',
#   '10,996',
#   '10,031',
#   '2,750',
#   '7,204',
#   '7,101',
#   '5,179',
#   '6,538',
#   '6,472',
#   '5,637',
#   '6,512',
#   '3,867',
#   '2,698',
#   '5,312',
#   '4,435',
#   '4,751',
#   '2,868',
#   '4,407',
#   '4,221',
#   '2,342',
#   '3,972',
#   '3,971',
#   '3,513',
#   '3,489',
#   '3,298',
#   '3,407',
#   '2,740',
#   '2,941',
#   '2,631',
#   '2,873',
#   '2,498',
#   '1,103',
#   '1,779',
#   '1,978',
#   '1,583',
#   '1,800',
#   '1,053',
#   '1,643',
#   '1,720',
#   723,
#   '1,258',
#   '1,253',
#   873,
#   '1,196',
#   556,
#   '1,248',
#   649,
#   '1,040',
#   '1,172',
#   '1,022',
# ...

# %%
df.head(50)
# Out:
#         Country,Other TotalCases  ... Tests/\n1M pop\n          Continent
# 0   \nNorth America\n    656,863  ...                       North America
# 1          \nEurope\n    949,489  ...                              Europe
# 2            \nAsia\n    325,145  ...                                Asia
# 3   \nSouth America\n     58,330  ...                       South America
# 4         \nOceania\n      7,924  ...                   Australia/Oceania
# 5          \nAfrica\n     17,008  ...                              Africa
# 6                \n\n        721  ...
# 7               World  2,015,480  ...                                 All
# 8                 USA    614,246  ...            9,367      North America
# 9               Spain    177,633  ...           12,833             Europe
# 10              Italy    162,488  ...           17,758             Europe
# 11             France    143,303  ...            5,114             Europe
# ...
